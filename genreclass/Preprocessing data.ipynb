# %%
# !pip install python_speech_features==0.6
# Out:
# Collecting python_speech_features==0.6
#   Using cached python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python_speech_features
#   Building wheel for python_speech_features (setup.py) ... done
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5889 sha256=b93c231013f8d830240abb52c86df5741b56ccae52a2eac924a4a07820f5356e
#   Stored in directory: /root/.cache/pip/wheels/09/a1/04/08e2688d2562d8f9ff89e77c6ddfbf7268e07dae1a6f22455e
# Successfully built python_speech_features
# Installing collected packages: python_speech_features
# Successfully installed python_speech_features-0.6
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
from python_speech_features import mfcc
import scipy.io.wavfile as wav
import numpy as np
from tempfile import TemporaryFile
import os
import pickle
import random 
import operator
import math
import numpy as np
import librosa
import librosa.display

import seaborn as sns
import json

# %%
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# %%
example_file = '/work/pop000.wav'

# %%
signal, sample_rate = librosa.load(example_file)

# %%
print(signal) #amplitude of the sound
# Out:
# [ 0.10225765  0.24458705  0.2634704  ... -0.52111185 -0.49635828
#  -0.3400721 ]

# %%
print(sample_rate) #the default rate
# Out:
# 22050

# %%
#plotting the waveform
plt.figure(figsize = (16,8))
librosa.display.waveshow(y =signal, sr =sample_rate, alpha=0.5)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveforming')
plt.show()

# %%
#Fourier transform fft - (Frequency domain)
fft = np.fft.fft(signal)

# %%
#calculating the magnitude
spectrum = np.abs(fft)

# %%
#recreating the frequency variable
f = np.linspace(0, sample_rate, len(spectrum))

# %%
#plotting the spectrum
plt.figure(figsize = (16,8))
plt.plot(f,spectrum, alpha=0.5)
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.title('Spectrum')
# Out:
# Text(0.5, 1.0, 'Spectrum')

# %% [markdown]
# There is strong magnitude for lower frequencies, and strong magnitude for the high frequencies

# %%
#taking the half of the freq and magnitude
left_spectrum = spectrum[:int(len(spectrum)/2)]
left_f = f[:int(len(spectrum)/2)]

# %%
# Plot the power spectrum
plt.figure(figsize=(16, 8))
plt.plot(left_f, left_spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Spectrogram (STFT)
hop_length = 512 # num. of samples
n_fft = 2048 # num. of samples for window

# %%
# Perform STFT
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrogram = np.abs(stft)

# %%
# Plot the Spectrogram
plt.figure(figsize=(16, 8))
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.title("Spectrogram")
# Out:
# Text(0.5, 1.0, 'Spectrogram')

# %% [markdown]
# This shows the changing spectra as a function of time

# %%
# Apply Logarithm to get values in Decibels
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# %%
# Plot the Spectrogram in Decibels
plt.figure(figsize=(16,8))
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %% [markdown]
# MFCCs divide the audio signal into short time frames and applying the Fourier transform to each frame. Its also becomes non-sensitive to small changes and variations in the spectrum. MFCCs extract relevant features from the audio that are differentiate the different music genres. This is why we want the MFCC feature.

# %%
# MFCCs (we use 13 MFCCs)
MFCCs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# %%
# Plot MFCCs
plt.figure(figsize=(16,8))
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")
# Out:
# Text(0.5, 1.0, 'MFCCs')

# %% [markdown]
# ### Get MFCCs for all the files in the dataset

# %%
dataset_path = "/datasets/my-drive/genre_wav"
json_path = "data_10.json"
sample_rate = 22050
track_duration = 30 # measured in seconds
samples_per_track = sample_rate * track_duration

# %%
classes = [a for a in os.listdir('/datasets/my-drive/genre_wav') if '.' not in a]
print(classes)
# Out:
# ['rock', 'pop', 'mpop', 'indie', 'hiphop', 'folk']

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along with genre labels.
    """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }
    global sample_rate

    samples_per_segment = int(samples_per_track / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-directory
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=sample_rate)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(y = signal[start:finish], sr = sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

    return

# %%
save_mfcc(dataset_path, json_path, num_segments=10)
# Out:
# /datasets/my-drive/genre_wav/pop/pop025.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop025.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop025.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop025.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop025.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop025.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop026.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop027.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop028.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop029.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop030.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop031.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop032.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop033.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop035.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop034.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop036.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop037.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop038.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop039.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop040.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop041.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop042.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop043.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop044.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:9
# /datasets/my-drive/genre_wav/pop/pop045.wav, segment:10
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:1
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:2
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:3
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:4
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:5
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:6
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:7
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:8
# /datasets/my-drive/genre_wav/pop/pop047.wav, segment:9
#
# Processing: indie
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie001.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie002.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie003.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie004.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie005.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie007.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie006.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie008.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie009.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie010.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie011.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie012.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie013.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie014.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie015.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie016.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie017.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie018.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie020.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie021.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie019.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie022.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie023.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie024.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie025.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie026.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie027.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie028.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie029.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie030.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie031.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie032.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie033.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie034.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie035.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie036.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie037.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie038.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie039.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie040.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie041.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie042.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie043.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie044.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie045.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie046.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie047.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie048.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie050.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie049.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie051.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie052.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie053.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie054.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie055.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie057.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie056.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie058.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie059.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie060.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie061.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie062.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie063.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie064.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie065.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie066.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie067.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie068.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie069.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie070.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie071.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie072.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie073.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie074.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie075.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie076.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie077.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie078.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie079.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie080.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie081.wav, segment:10
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie083.wav, segment:9
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:1
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:2
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:3
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:4
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:5
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:6
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:7
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:8
# /datasets/my-drive/genre_wav/indie/indie082.wav, segment:9

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b07dafd9-52d0-496f-b99d-0bc116229374' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
