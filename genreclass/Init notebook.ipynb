# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (22.0.4)
# Collecting python_speech_features==0.6
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pytube==15.0.0
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 KB 8.3 MB/s eta 0:00:00
# Collecting streamlit
#   Downloading streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 69.0 MB/s eta 0:00:00
# Requirement already satisfied: isodate in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 6)) (1.2.5)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 7)) (1.23.4)
# Requirement already satisfied: seaborn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 9)) (3.6.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 KB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (9.2.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (4.2.2)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: packaging>=14.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (21.3)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.0 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (8.1.3)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: tzlocal>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (4.2)
# Requirement already satisfied: requests>=2.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (2.28.1)
# Requirement already satisfied: protobuf<4,>=3.12 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (4.4.0)
# Requirement already satisfied: pyarrow>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (9.0.0)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (8.1.0)
# Collecting rich>=10.11.0
#   Downloading rich-13.3.5-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 36.0 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 94.8 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (5.2.0)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.0.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 4)) (6.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from isodate->-r ./requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 6)) (2022.5)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 9)) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 9)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 9)) (4.37.4)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_17_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.6 MB/s eta 0:00:00
# Collecting pooch<1.7,>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from librosa->-r ./requirements.txt (line 11)) (1.9.3)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: joblib>=0.14 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from librosa->-r ./requirements.txt (line 11)) (1.2.0)
# Collecting numba>=0.51.0
#   Downloading numba-0.57.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 115.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from librosa->-r ./requirements.txt (line 11)) (1.1.2)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 88.7 MB/s eta 0:00:00
# Collecting msgpack>=1.0
#   Downloading msgpack-1.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 KB 47.6 MB/s eta 0:00:00
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 54.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: decorator>=4.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from librosa->-r ./requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (0.4)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (2.11.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit->-r ./requirements.txt (line 4)) (3.9.0)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 33.6 MB/s eta 0:00:00
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 4)) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 4)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 4)) (3.4)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rich>=10.11.0->streamlit->-r ./requirements.txt (line 4)) (2.13.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa->-r ./requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa->-r ./requirements.txt (line 11)) (1.15.1)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal>=1.1->streamlit->-r ./requirements.txt (line 4)) (0.1.0.post0)
# Requirement already satisfied: pycparser in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r ./requirements.txt (line 11)) (2.21)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->-r ./requirements.txt (line 4)) (58.1.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tzdata in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->-r ./requirements.txt (line 4)) (2022.5)
# Building wheels for collected packages: python_speech_features, sklearn, audioread, validators
#   Building wheel for python_speech_features (setup.py): started
#   Building wheel for python_speech_features (setup.py): finished with status 'done'
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5889 sha256=7ddec0cc17099cb51725f4e8893594f82111242b1f1568646d67c30933fb77e0
#   Stored in directory: /root/.cache/pip/wheels/09/a1/04/08e2688d2562d8f9ff89e77c6ddfbf7268e07dae1a6f22455e
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2359 sha256=036df8545fe328eff12e5102e05430bfc03755402c7cc83c43e982fd49958590
#   Stored in directory: /root/.cache/pip/wheels/36/49/c9/2374f1dee1b599effabf63d948635e6608f62d0ccde027b7e2
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23707 sha256=b12cf1a5f74dfe6458d51659f8ba2bc97412cc8e6ab302a2a0fb9f2fb676fc05
#   Stored in directory: /root/.cache/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=7351146dc6ee51968c85cf32d56c644154d1472b5b86c88514d7f2fe5ccb97db
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built python_speech_features sklearn audioread validators
# Installing collected packages: sklearn, python_speech_features, msgpack, appdirs, watchdog, validators, toml, soxr, smmap, pytube, pympler, mdurl, llvmlite, lazy-loader, blinker, audioread, soundfile, pydeck, pooch, numba, markdown-it-py, gitdb, rich, librosa, gitpython, streamlit
# Successfully installed appdirs-1.4.4 audioread-3.0.0 blinker-1.6.2 gitdb-4.0.10 gitpython-3.1.31 lazy-loader-0.2 librosa-0.10.0.post2 llvmlite-0.40.0 markdown-it-py-2.2.0 mdurl-0.1.2 msgpack-1.0.5 numba-0.57.0 pooch-1.6.0 pydeck-0.8.1b0 pympler-1.0.1 python_speech_features-0.6 pytube-15.0.0 rich-13.3.5 sklearn-0.0.post5 smmap-5.0.0 soundfile-0.12.1 soxr-0.3.5 streamlit-1.22.0 toml-0.10.2 validators-0.20.0 watchdog-3.0.0
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b07dafd9-52d0-496f-b99d-0bc116229374' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
